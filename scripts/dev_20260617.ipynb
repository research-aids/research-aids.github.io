# %%
from tqdm import tqdm
import os
from glob import glob
import yaml
import json
import re
import argparse
from io import StringIO


# unused: from docx import Document
from Markdown2docx import Markdown2docx
# from md2docx_python.src.md2docx_python import markdown_to_word
from markdown_pdf import MarkdownPdf, Section

# from ResearchAids import ResearchAid
# from md_to_website import download_button, front_matter

os.chdir("../../research-aids/")

from scripts.ResearchAids import ResearchAid
from scripts.md_to_website import download_button, front_matter

# %%
EXPORT_DIR = "EXPORTS"
GITHUB_RAW_BASE_URL = "https://raw.githubusercontent.com/colonial-heritage/research-aids/refs/heads/main/"


def parse_filepath(fp):
    *pref, published, level, lang, fname = fp.split(os.path.sep)
    aid_name, extension = fname.split(".")
    return published, level, lang, aid_name


def get_export_path(orig_path, export_folder, extension=None, make_dirs=True):
    published, level, lang, name = parse_filepath(orig_path)
    if not extension:
        extension = export_folder.lower()
    extension = ("." + extension if not extension.startswith(".") else extension)
    export_path =  os.path.join(EXPORT_DIR, export_folder, published, level, lang, name) + extension
    os.makedirs(os.path.dirname(export_path), exist_ok=True)
    return export_path, (published, level, lang, name)


def export_markdown(f):
    md_name, _ = get_export_path(f, "MD")
    with open(f) as handle:
        yaml_content = yaml.safe_load(handle)
        ra = ResearchAid(yaml_content, raise_parsing_error=True)
        if ra._parsed:
            md_content = ra()
            with open(md_name, "w") as md_handle:
                md_handle.write(md_content)

            return md_content
        else:
            raise ValueError(f"{f} didn't parse")

def export_pdf(f, md_content):
    pdf_name, _ = get_export_path(f, "PDF")
        
    pdf = MarkdownPdf()#toc_level=2)
    pdf.add_section(Section(md_content, toc=False))
    pdf.meta["title"] = "NAME"
    pdf.meta["author"] = "wreints"
    # print(f"saving {pdf_name}")
    # pdf.save(pdf_name)

# %%
for cur_dir in ("published", "review"):
    eng = glob(f"{cur_dir}/*/English/*.yml")
    dutch = glob(f"{cur_dir}/*/Dutch/*.yml")
    # top = glob(f"{BASE_DIR}/TopLevel/*.yml")
    
    yaml_files = sorted(dutch + eng)

    for f in tqdm(yaml_files):
    # print(f"processing {f}...")
        # print(f)
        md_content = export_markdown(f)
        export_pdf(f, md_content)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:02<00:00, 34.04it/s]
#  70%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                        | 7/10 [00:00<00:00, 52.67it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 11
#       6 yaml_files = sorted(dutch + eng)
#       8 for f in tqdm(yaml_files):
#       9 # print(f"processing {f}...")
#      10     # print(f)
# ---> 11     md_content = export_markdown(f)
#      12     export_pdf(f, md_content)
#
# Cell In[19], line 25, in export_markdown(f)
#      23 with open(f) as handle:
#      24     yaml_content = yaml.safe_load(handle)
# ---> 25     ra = ResearchAid(yaml_content, raise_parsing_error=True)
#      26     if ra._parsed:
#      27         md_content = ra()
#
# File ~/Desktop/NIOD/research-aids/scripts/ResearchAids.py:93, in ResearchAid.__init__(self, yml, raise_parsing_error)
#      91 self._error_msg = e
#      92 if raise_parsing_error:
# ---> 93     raise e
#
# File ~/Desktop/NIOD/research-aids/scripts/ResearchAids.py:87, in ResearchAid.__init__(self, yml, raise_parsing_error)
#      83     self.date = datetime.today().strftime("%Y-%m-%d")
#      86 try:
# ---> 87     self.level = self.get_level(self.level_id)(yml)
#      88     self._parsed = True
#      89 except Exception as e:
#
# File ~/Desktop/NIOD/research-aids/scripts/ResearchAids.py:281, in Level3.__init__(self, yml)
#     280 def __init__(self, yml):
# --> 281     super().__init__(yml)
#
# File ~/Desktop/NIOD/research-aids/scripts/ResearchAids.py:228, in Level2.__init__(self, yml)
#     226 self.related_aids = self.parse_related_aids(yml["RelatedAides"])
#     227 self.relevant_data = self.parse_relevant_data(yml["Relevant data"])
# --> 228 self.sources = self.parse_sources(yml["Sources"]) if (("Sources" in yml) and yml["Sources"]) else "THIS RA HAS NO SOURCES"
#
# File ~/Desktop/NIOD/research-aids/scripts/ResearchAids.py:253, in Level2.parse_sources(self, yml)
#     251 for source_lvl, source_ls in yml.items():
#     252     md += f"## {source_lvl}\n\n"
# --> 253     for source in source_ls: #SORT
#     254         # 'Type of source', 'Name', 'Link', 'Description and remarks'
#     255         source_md = f"{source['Type of source']}:\n  > *{source['Name']}*"
#     256         # links_md = ", ".join([f"{v} (_{k}_)" for d in source['Link'] for k, v in d.items()])
#     257         # links_md = "(" + links_md + ")"
#
# TypeError: 'NoneType' object is not iterable

# %%
with open(f) as handle:
        yaml_content = yaml.safe_load(handle)

# %%
from scripts.ResearchAids import Level2
Level2(yaml_content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 from scripts.ResearchAids import Level2
# ----> 2 Level2(yaml_content)
#
# File ~/Desktop/NIOD/research-aids/scripts/ResearchAids.py:228, in Level2.__init__(self, yml)
#     226 self.related_aids = self.parse_related_aids(yml["RelatedAides"])
#     227 self.relevant_data = self.parse_relevant_data(yml["Relevant data"])
# --> 228 self.sources = self.parse_sources(yml["Sources"]) if (("Sources" in yml) and yml["Sources"]) else "THIS RA HAS NO SOURCES"
#
# File ~/Desktop/NIOD/research-aids/scripts/ResearchAids.py:253, in Level2.parse_sources(self, yml)
#     251 for source_lvl, source_ls in yml.items():
#     252     md += f"## {source_lvl}\n\n"
# --> 253     for source in source_ls: #SORT
#     254         # 'Type of source', 'Name', 'Link', 'Description and remarks'
#     255         source_md = f"{source['Type of source']}:\n  > *{source['Name']}*"
#     256         # links_md = ", ".join([f"{v} (_{k}_)" for d in source['Link'] for k, v in d.items()])
#     257         # links_md = "(" + links_md + ")"
#
# TypeError: 'NoneType' object is not iterable
